# %%
# !pip install sqlalchemy psycopg2-binary
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 37.3 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append("/content/drive/MyDrive/Project 2. Marketing Campaign Analytics Pipeline")

import pipeline
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Project 2. Marketing Campaign Analytics Pipeline/Marketing_with_new_data.csv")
df.head()
# Out:
#    id      c_date    campaign_name    category  campaign_id  impressions  \
# 0   1  2021-02-01   facebook_tier1      social       349043       148263
# 1   2  2021-02-01   facebOOK_tier2      social       348934       220688
# 2   3  2021-02-01       google_hot      search     89459845        22850
# 3   4  2021-02-01      google_wide      search       127823       147038
# 4   5  2021-02-01  youtube_blogger  influencer        10934       225800
#
#    mark_spent  clicks  leads  orders  revenue
# 0     7307.37    1210     13       1   4981.0
# 1    16300.20    1640     48       3  14962.0
# 2     5221.60     457      9       1   7981.0
# 3     6037.00    1196     24       1   2114.0
# 4    29962.20    2258     49      10  84490.0

# %%
df.columns
# Out:
# Index(['id', 'c_date', 'campaign_name', 'category', 'campaign_id',
#        'impressions', 'mark_spent', 'clicks', 'leads', 'orders', 'revenue'],
#       dtype='object')

# %%
pipeline.run_pipeline(df)
# Out:
# ✅ Pipeline finished successfully.
#  - Rows in staging: 276
#  - Rows in fact_campaigns_clean: 276
#  - Columns in fact_campaigns_clean:
# ['id', 'c_date', 'campaign_name', 'category', 'campaign_id', 'impressions', 'mark_spent', 'clicks', 'leads', 'orders', 'revenue', 'ctr_pct', 'cpc', 'cpa', 'conversionrate_pct', 'roas', 'profit', 'leadrate_pct', 'year', 'month', 'weekday', 'is_weekend']
#    id      c_date    campaign_name    category  campaign_id  impressions  \
# 0   1  2021-02-01   facebook_tier1      social       349043       148263
# 1   2  2021-02-01   facebOOK_tier2      social       348934       220688
# 2   3  2021-02-01       google_hot      search     89459845        22850
# 3   4  2021-02-01      google_wide      search       127823       147038
# 4   5  2021-02-01  youtube_blogger  influencer        10934       225800
#
#    mark_spent  clicks  leads  orders  ...    cpc      cpa  conversionrate_pct  \
# ...
